# %% [markdown]
# Check out the various way to read data in and out of Pandas.
# http://pandas.pydata.org/pandas-docs/stable/io.html

# %%
import pandas as pd

xl = pd.ExcelFile("SampleData.xlsx")

# %%
xl

# %%
xl.sheet_names
# Out:
# ['Instructions', 'SalesOrders', 'MyLinks']

# %%
df = xl.parse("SalesOrders")

# %%
df
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2015-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2015-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2015-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2015-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2015-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2015-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2015-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2015-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2015-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2015-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2015-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2015-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2015-07-29     East    Parent   Binder     81      19.99  1619.19
# ...
